# %%
import pandas as pd
import pyautogui as aui
from PIL import Image
from pytesseract import image_to_string
import win32clipboard
import time
import os

# %% [markdown]
# # 读取文件

# %%
firm_codes = pd.read_excel('审计数据范围（安永）(1).xls')

# %%
firm_codes['编码'] = firm_codes['编码'].astype(str)
firm_codes['code_length'] = firm_codes['编码'].apply(lambda x:len(x))

# %% [markdown]
# # 创建文件夹

# %%
cwd = os.getcwd()
file_path = []
for idx in firm_codes.index:
    folder_name = firm_codes.loc[idx,'编码']+ '-' + firm_codes.loc[idx,'名称']
    code0 = (firm_codes.loc[idx,'编码']=='0')
    code1 = (firm_codes.loc[idx,'编码']=='1')
    code3 = (firm_codes.loc[idx,'编码']=='3')
    code5 = (firm_codes.loc[idx,'编码']=='5')
    
    cond1_1 = firm_codes.loc[idx,'编码'].startswith('1')
    cond1_2 = (len(firm_codes.loc[idx,'编码'])==3)
    cond1_3 = (len(firm_codes.loc[idx,'编码'])==5)
    cond1_4 = (len(firm_codes.loc[idx,'编码'])==7)
    cond1_5 = (firm_codes.loc[idx,'编码'].strip()=='1601')
                    
    cond2_1 = firm_codes.loc[idx,'编码'].startswith('3')
    cond2_2 = len(firm_codes.loc[idx,'编码'])==3
    
    cond3_1 = firm_codes.loc[idx,'编码'].startswith('5')
    cond3_2 = len(firm_codes.loc[idx,'编码'])==3
    

    if  code0: # 文件夹
        grand_folder = cwd+'\\'+ folder_name
        if not os.path.exists(grand_folder):
            os.mkdir(grand_folder)
                    
    elif (code1 or code3 or code5): # 文件夹
        parent_folder = grand_folder + '\\' + folder_name
        if not os.path.exists(parent_folder):
            os.mkdir(parent_folder)
    
    elif cond1_1 and (cond1_2 or cond1_3): # 文件夹
        child_folder = parent_folder + '\\'+ folder_name
        if not os.path.exists(child_folder):
            os.mkdir(child_folder)    

    if cond1_1 and (cond1_2 or cond1_4 or cond1_5): # 文件
        file_path.append(child_folder + '\\'+ firm_codes.loc[idx,'编码'] + '-0002' + '\\' + firm_codes.loc[idx,'名称'])
            
    elif cond2_1 and cond2_2: # 文件
        file_path.append(parent_folder+'\\' +firm_codes.loc[idx,'编码'] + '-0006' + '\\' + firm_codes.loc[idx,'名称'])

    elif cond3_1 and cond3_2: # 文件
        file_path.append(parent_folder + '\\' + firm_codes.loc[idx,'编码'] + '-0005' + '\\' + firm_codes.loc[idx,'名称'])

# %%
file_path[100:110]
# Out:
# ['D:\\Leadingworks\\ExportTable\\0-领地集团\\1-领地集团（房地产板块汇总）\\10210-领地集团（河南区域汇总）\\1021008-0002\\郑州领域房地产开发有限公司',
#  'D:\\Leadingworks\\ExportTable\\0-领地集团\\1-领地集团（房地产板块汇总）\\10210-领地集团（河南区域汇总）\\1021010-0002\\商丘川达房地产开发有限公司',
#  'D:\\Leadingworks\\ExportTable\\0-领地集团\\1-领地集团（房地产板块汇总）\\10210-领地集团（河南区域汇总）\\1021011-0002\\郑州川达房地产开发有限公司',
#  'D:\\Leadingworks\\ExportTable\\0-领地集团\\1-领地集团（房地产板块汇总）\\10210-领地集团（河南区域汇总）\\1021012-0002\\郑州泛达房地产开发有限公司',
#  'D:\\Leadingworks\\ExportTable\\0-领地集团\\1-领地集团（房地产板块汇总）\\10211-领地集团（其他区域汇总）\\1021102-0002\\广西领地房地产开发有限公司',
#  'D:\\Leadingworks\\ExportTable\\0-领地集团\\1-领地集团（房地产板块汇总）\\10211-领地集团（其他区域汇总）\\1021103-0002\\四川利保清大投资有限公司',
#  'D:\\Leadingworks\\ExportTable\\0-领地集团\\1-领地集团（房地产板块汇总）\\10211-领地集团（其他区域汇总）\\1021104-0002\\大连领地房地产开发有限公司',
#  'D:\\Leadingworks\\ExportTable\\0-领地集团\\1-领地集团（房地产板块汇总）\\10211-领地集团（其他区域汇总）\\1021105-0002\\武汉领地房地产开发有限公司',
#  'D:\\Leadingworks\\ExportTable\\0-领地集团\\1-领地集团（房地产板块汇总）\\10211-领地集团（其他区域汇总）\\1601-0002\\吉林省领地房地产开发有限公司',
#  'D:\\Leadingworks\\ExportTable\\0-领地集团\\1-领地集团（房地产板块汇总）\\10220-领地集团（南充区域汇总）\\1022001-0002\\南充领创房地产开发有限公司']

# %% [markdown]
# # 操作剪切板

# %%
def set_clipboard_text(text):
    win32clipboard.OpenClipboard()
    win32clipboard.EmptyClipboard()
    win32clipboard.SetClipboardText(text)
    win32clipboard.CloseClipboard()


def get_clipboard_text():
    win32clipboard.OpenClipboard()
    text = win32clipboard.GetClipboardData()
    win32clipboard.CloseClipboard()
    return text


def paste_text(text):
    aui.hotkey('ctrl','a')
    set_clipboard_text(text)
    aui.hotkey('ctrl','v')

# %% [markdown]
# # hotkey

# %%
def hotkey(key,n=1):
    while n>0:
        aui.hotkey(key)
        n-=1

# %% [markdown]
# # maximize用友窗口

# %%
# yonyou = aui.getActiveWindow()
yonyou = aui.getWindowsWithTitle('Yonyou UClient')[0] # [window]
yonyou.maximize()

# %% [markdown]
# # 打开NC

# %%
aui.leftClick(300,419)

# %% [markdown]
# # 登录

# %%
while True:
#     aui.screenshot('login.png',region=(160,120,666,430))
    aui.screenshot('login.png',region=(625,210,666,430))
    img_str = image_to_string(Image.open('login.png'))
    if "NC" in img_str:
#         aui.leftClick(482,380)
        aui.leftClick(960,470)
#         maxw,maxh = aui.size()
#         yonyou.resizeTo(maxw,maxh)
        
        paste_text('yangsj1001')
        aui.typewrite(['enter'])
        
        paste_text('leadingYSJ888')
        aui.typewrite(['enter'])
        
        already_online = aui.getWindowsWithTitle('提示')
        while already_online:
            aui.hotkey('enter')
            break
        break

# %% [markdown]
# # 打开序时账

# %%
while True:
    aui.doubleClick(592,487) # 序时账
    aui.leftClick(30,180) #查询
    try:
        query_window = aui.getWindowsWithTitle('凭证查询')[0]
        if query_window.visible==1:
            query_window.close()
            break
    except IndexError:
        pass

# %% [markdown]
# # 查询

# %%
def query(first_query=True):
    aui.leftClick(30,180) #查询
    
    while True:
        try:
            window_visible = aui.getWindowsWithTitle('凭证查询')[0].visible
            if window_visible==1:
                break
        except IndexError:
            aui.leftClick(30,180) #失败再次点击查询
    
    #选择账簿
    aui.leftClick(720,230)
    #aui.hotkey('tab',duration=0.5)
    paste_text(firm_code)
    aui.hotkey('enter')
    
    #选择时间
    # start
    # aui.leftClick(810,322)
    # time.sleep(0.5)
    # aui.scroll(10,808,425)
    # aui.leftClick(783,349)
    
    time.sleep(2)
    aui.doubleClick(782,323)
    aui.typewrite('01')
    
    #end
    # aui.leftClick(988,322)
    # aui.vscroll(-10,963,413)
    # aui.leftClick(956,435)
    time.sleep(1)
    aui.doubleClick(960,323)
    aui.typewrite('09')    
    
    if first_query:
        aui.leftClick(666,850,duration=2) #合并查询
    
    aui.moveTo(1144,850)
    time.sleep(2) # 等待确认
    aui.leftClick(1144,850) # 确认
    
def check_error():
    #确认查询,账簿选择错误
    tips_w = aui.getWindowsWithTitle('提示')
    error_w = aui.getWindowsWithTitle('错误')
    while tips_w or error_w:
        aui.hotkey('enter')
        try:
            if aui.getWindowsWithTitle('凭证查询')[0].isActive:
                query()
                check_error()
        except IndexError:
            query(first_query=False)
            check_error()
        break

# %%
# first_file = True
for path in file_path[41:]:
    firm_name = os.path.basename(path)
    firm_code = os.path.basename(os.path.dirname(path))
    dirname = os.path.dirname(os.path.dirname(path))
    target_file = dirname + '\\' + firm_name + ' 序时账19.1-19.9.xls'
    
    if first_file:
        query()
        check_error()
    else:
        query(first_query=False)

    #打印设置
    c = 0
    while True:
        aui.screenshot('查询已结束.png',region = (0,965,100,26))
        query_finish_str = image_to_string(Image.open('查询已结束.png'),lang='chi_sim')
        if query_finish_str!='':
            aui.screenshot('time.png',region = (62,214,128,30))
            time_str = image_to_string(Image.open('time.png'))
            time_cond = (time_str.strip().strip('\'').replace('-','').replace('—','') != "201901201909") #2019-01—2019-09
            if time_cond and c<5:
               # aui.hotkey('shift')
                query(first_query=False)
                check_error()
                c +=1
            elif time_cond and c==5:
                break
            else:
                break
                
    aui.leftClick(528,180) #打印
    while True:
        try:
            window_visible = aui.getWindowsWithTitle('打印')[0].visible
            if window_visible==1:
                break
        except IndexError:
            pass
    
    aui.leftClick(842,415) #按显示打印
    hotkey('tab',2) #预览
    aui.hotkey('enter')
    
    while True:
        try:
            window_visible = aui.getWindowsWithTitle('打印预览')[0].visible
            if window_visible==1:
                break
        except IndexError:
            pass
    
    aui.leftClick(1720,870) #输出
    while True:
        try:
            window_visible = aui.getWindowsWithTitle('输出到文件')[0].visible
            if window_visible==1:
                break
        except IndexError:
            pass
    
    #选择目标文件
    hotkey('tab',4) 
    aui.hotkey('enter')
    paste_text(target_file)
    aui.typewrite(['enter'])
    
    # 工作表前缀
    hotkey('tab',3)
    paste_text(firm_name)
    
    # 行数
    aui.hotkey('tab')
    paste_text('200000')
    # 确定
    aui.hotkey('tab')
    aui.hotkey('enter')

#     print(aui.getAllTitles())
    while True:
        try:
            window_active = aui.getWindowsWithTitle('文件已存在')[0].isActive
            if window_active:
                aui.leftClick(742,552) #覆盖
                hotkey('enter',4)
        except IndexError:
            pass

        try:
            window_active = aui.getWindowsWithTitle('导出Excel')[0].isActive
            if window_active:
                aui.leftClick(801,486) # 打印完毕后关闭
                break
        except IndexError:
            time.sleep(1)
            pass

    while True:
        try:
            aui.getWindowsWithTitle('打印预览')[0].close()
        except IndexError:
            break
    
    first_file = False

# %%
result_dict = {}

for folder in os.listdir(grand_folder): #第二层
    for file in os.listdir(grand_folder+ '\\'+folder): #第三层
#         print(file)
        if os.path.isdir(grand_folder+ '\\' + folder + '\\' +file):
            for f in os.listdir(grand_folder+ '\\' + folder + '\\' +file):
                f_path = grand_folder+ '\\' + folder + '\\' + file + '\\' +f
#                 print(f_path)
                result_df = pd.read_excel(f_path)
                time_period = result_df.iloc[4,0]
                if '2019-01--2019-09' in time_period:
                    print('{0:<20}{1:<40}'.format(time_period+' 【 完成 】 ',f))
                else:
                    print('{0:<20}{1:<40}'.format(time_period+' 【 失败 】 ',f))
                result_dict[f.strip(' 序时账19.1-19.9xls')] = time_period.strip('期间：')
                
        else:
            f_path = grand_folder+ '\\' + folder + '\\' +file
            result_df = pd.read_excel(f_path)
            time_period = result_df.iloc[4,0]
            if '2019-01--2019-09' in time_period:
                print('{0:<20}{1:<40}'.format(time_period+' 【 完成 】 ',file))
            else:
                print('{0:<20}{1:<40}'.format(time_period+' 【 失败 】 ',file))
            result_dict[file.strip(' 序时账19.1-19.9xls')] = time_period.strip('期间：')
# Out:
# 期间：2019-01--2019-09 【 完成 】 领地集团股份有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 四川宏晟悦华房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 四川御成瑞海房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 四川新领域房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 四川领地泛亚房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 成都京领英赫置业有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 成都天府新区圣域房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 成都悦航房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 成都新隆置业有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 成都新领源房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 成都汉景实业有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 成都源地房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 成都领地泛太房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 成都领悦房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 成都领跑房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 新津菁阳投资有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 郫县升达置业有限责任公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 领地集团股份有限公司环球金融中心项目部 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 乐山华汇达房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 乐山华瑞房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 乐山川达房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 乐山海纳房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 乐山领地房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 乐山领悦房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 四川省瑞与祥房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 沐川海纳房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 领地集团股份有限公司乐山分公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 仁寿领创房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 四川凯旋房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 四川源地房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 四川长寿坊房地产开发有限责任公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 四川陆地房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 眉山华汇达房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 眉山华瑞宏大置业有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 眉山华瑞房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 眉山唯创房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-07--2019-09 【 失败 】 眉山川瑞达房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 眉山川达房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 眉山泛亚房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 眉山海纳房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 眉山青竹沟旅游开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 眉山领地房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-07--2019-09 【 失败 】 眉山领悦房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 领地集团股份有限公司眉山分公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 佛山市南海领地房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 佛山市禅城区领悦房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 广东领地房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 广东领悦房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 惠州领地房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 惠州领悦房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 汕尾市领地房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 深圳丰盛实力钢管有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 深圳市荣启投资发展有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 张家口领域房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 承德川达房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 承德市双滦区海建房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 承德市君越房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 承德领地房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 河北都能房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 雅安唯创房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-07--2019-09 【 失败 】 雅安圣域房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 雅安城投领地房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 雅安川达房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-07--2019-09 【 失败 】 雅安恒量房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-07--2019-09 【 失败 】 雅安新领域房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 雅安泛亚房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 雅安海纳房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 雅安源地房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 雅安金宏房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 雅安领地房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 雅安领悦房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-07--2019-09 【 失败 】 雅安鼎创房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 攀枝花领悦房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-06--2019-09 【 失败 】 米易川达房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-06--2019-09 【 失败 】 米易海纳房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 西昌唯创房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 西昌市海诚旅游开发有限公司 序时账19.1-19.9.xls
# 期间：2019-07--2019-09 【 失败 】 西昌恒量房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 西昌源地房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 西昌领创房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 西昌领地房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 西昌领域房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 西昌领悦房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 乌鲁木齐领创汇通房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 乌鲁木齐领地凯悦房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 库尔勒领创房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 新疆兆龙诚祥房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 新疆民佰房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 新疆领地房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 绵阳嘉瑞诚房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 绵阳市三和实业有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 绵阳市宇航数码科技有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 绵阳金泰实业有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 绵阳鸿远领悦房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 商丘川达房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 郑州川达房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 郑州泛达房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 郑州领域房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 驻马店伟昇房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 驻马店伟汇房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 驻马店伟顺房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 驻马店皇家驿站文化旅游开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 驻马店盛世伟光房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 驻马店盛世汇通房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 四川利保清大投资有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 大连领地房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 广西领地房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 武汉领地房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 南充唯创房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 南充泛亚房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 南充海纳房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 南充领创房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 南充领悦房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 凯里凯龙置业有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 凯里唯创房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 贵州川达房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 贵州省领悦房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 贵州领地房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-07--2019-09 【 失败 】 重庆新唯创企业管理咨询有限责任公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 重庆泛太房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 荆州领创房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-07--2019-09 【 失败 】 荆州领悦房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 徐州川达房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 徐州源地房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 徐州领源房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 云南川达房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 昆明网龙计算机信息技术有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 西藏亿美新实业有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 乐山领地房地产开发有限公司平台 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 北京清大怡豪投资有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 四川领域企业管理咨询有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 成都恒量企业管理咨询有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 湖南省领创房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 绵阳华瑞达房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 绵阳恒量房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 绵阳泛太亚房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 绵阳盛兴泰来科技有限责任公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 绵阳鑫亮平科技有限责任公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 绵阳领创汇通房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 绵阳领地房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 西安都能房地产开发有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 重庆源地川达企业管理咨询有限公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 成都汉景实业有限公司青羊分公司 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 西昌唯创房地产开发有限公司隐居酒店 序时账19.1-19.9.xls
# 期间：2019-01--2019-09 【 完成 】 西昌嘉悦蜀韵酒店管理有限公司 序时账19.1-19.9.xls

# %%
# result_dict
with open('序时账记录.txt',mode='w',encoding='utf8') as f:
    for k,v in result_dict.items():
        f.write('{0:<20}{1:<40}\n'.format(v,k))
