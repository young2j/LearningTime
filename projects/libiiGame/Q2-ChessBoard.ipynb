# %%
def max_paths_num(m,n):
    if m ==1 or n ==1:
        return 1
    return max_paths_num(m-1,n)+max_paths_num(m,n-1)

# %%
# %%time
max_paths_num(18,18)
# Out:
# Wall time: 11min 29s
# 2333606220

# %%
from scipy.special import comb

# %%
# %%time
comb(18+18-2,18-1)
# Out:
# Wall time: 56.1 ms
# 2333606220.0
